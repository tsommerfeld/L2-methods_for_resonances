# %%
from sympy import init_session
init_session()
# Out:
# IPython console for SymPy 1.5.1 (Python 3.6.9-64-bit) (ground types: gmpy)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.5.1/

# %%
#init_printing?

# %% [markdown]
# ### Parameters and two Gaussians

# %%
rc, a, a1, a2 = symbols('rc, a, a1 a2', positive=True, real=True)

# %%
u1=x**2*exp(-a1*x**2)
u2=x**2*exp(-a2*x**2)
gp=x**4*exp(-a*x**2)
w=(x-rc)**2
u1, u2, gp, w
# Out:
# ⎛         2           2          2            ⎞
# ⎜ 2  -a₁⋅x    2  -a₂⋅x    4  -a⋅x            2⎟
# ⎝x ⋅ℯ      , x ⋅ℯ      , x ⋅ℯ     , (-rc + x) ⎠

# %% [markdown]
# <br>
#
# ### Radial wavefunction $u$
# We don't solve the radial equation for $R(r)$, but rather for $u(r) = r \cdot R(r)$.
# So, if $R$ is a s-function, $u$ is a p-function, and if $R$ is a p-function, $u$ is a d-function, etc. <br>
#
# $S = \int r^2dr R^2 = \int dr\, u^2$<br>
# $T = \int r^2dr R_1 \hat{T} R_2 = \int dr\, u_1\, \frac{d^2}{dr^2} \, u_2 $
# <br>

# %% [markdown]
# ### Normalization constant

# %%
N=integrate(u1*u1, (x, 0, oo))
N
# Out:
# 3⋅√2⋅√π
# ────────
#      5/2
# 64⋅a₁

# %%
1/sqrt(N)

# %%
printing.sstrrepr(1/sqrt(N))

# %% [markdown]
# ### CAP

# %%
W=integrate(u1*w*u2, (x, rc, oo))
W
# Out:
#     ⎛⎛                                            2          ⎞
#     ⎜⎜        _________    ⎛     _________⎞    -rc ⋅(a₁ + a₂)⎟ ⎛     4
#   7 ⎜⎝√π⋅rc⋅╲╱ a₁ + a₂ ⋅erf⎝rc⋅╲╱ a₁ + a₂ ⎠ + ℯ              ⎠⋅⎝28⋅rc ⋅(a₁ + a
# rc ⋅⎜─────────────────────────────────────────────────────────────────────────
#     ⎜                                                 6          3
#     ⎝                                            28⋅rc ⋅(a₁ + a₂)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#   2     2                      ⎞      ⎛     6          3         4          2
# ₂)  + rc ⋅(70⋅a₁ + 70⋅a₂) + 105⎠   √π⋅⎝56⋅rc ⋅(a₁ + a₂)  + 140⋅rc ⋅(a₁ + a₂)
# ──────────────────────────────── - ───────────────────────────────────────────
#                                                                              7
#                                                                         56⋅rc
# ──────────────────────────────────────────────────────────────────────────────
#                                    2
#
#
#                                                                        ⎞
#     2                        ⎞    ⎛     _________⎞                     ⎟
# + rc ⋅(210⋅a₁ + 210⋅a₂) + 105⎠⋅erf⎝rc⋅╲╱ a₁ + a₂ ⎠         15⋅√π       ⎟     7
# ────────────────────────────────────────────────── + ──────────────────⎟   rc
#           7/2                                            7          7/2⎟
# ⋅(a₁ + a₂)                                           8⋅rc ⋅(a₁ + a₂)   ⎠
# ──────────────────────────────────────────────────────────────────────── + ───
#
#
#
#  ⎛                              ⎛                                            2
#  ⎜  ⎛  2                      ⎞ ⎜        _________    ⎛     _________⎞    -rc
#  ⎜  ⎝rc ⋅(-10⋅a₁ - 10⋅a₂) - 15⎠⋅⎝√π⋅rc⋅╲╱ a₁ + a₂ ⋅erf⎝rc⋅╲╱ a₁ + a₂ ⎠ + ℯ
# ⋅⎜- ──────────────────────────────────────────────────────────────────────────
#  ⎜                                         4          2
#  ⎝                                    10⋅rc ⋅(a₁ + a₂)
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#           ⎞
# ⋅(a₁ + a₂)⎟      ⎛       4          2     2                      ⎞    ⎛     __
#           ⎠   √π⋅⎝- 20⋅rc ⋅(a₁ + a₂)  + rc ⋅(-30⋅a₁ - 30⋅a₂) - 15⎠⋅erf⎝rc⋅╲╱ a
# ─────────── + ────────────────────────────────────────────────────────────────
#                                              5          5/2
#                                         20⋅rc ⋅(a₁ + a₂)
# ──────────────────────────────────────────────────────────────────────────────
#              2
#
#
#                              ⎞
# _______⎞                     ⎟
# ₁ + a₂ ⎠          3⋅√π       ⎟
# ──────── + ──────────────────⎟
#                5          5/2⎟      ⎛  4          2     2                  ⎞
#            4⋅rc ⋅(a₁ + a₂)   ⎠   rc⋅⎝rc ⋅(a₁ + a₂)  + rc ⋅(2⋅a₁ + 2⋅a₂) + 2⎠⋅ℯ
# ────────────────────────────── - ─────────────────────────────────────────────
#                                                                    3
#                                                           (a₁ + a₂)
#
#
#
#
#    2
# -rc ⋅(a₁ + a₂)
#
# ──────────────

# %%
Ws=W.simplify()
Ws
# Out:
#  ⎛                           2
#  ⎜          2   _________  rc ⋅(a₁ + a₂)    ⎛     _________⎞             2   _
# -⎝6⋅√π⋅a₁⋅rc ⋅╲╱ a₁ + a₂ ⋅ℯ             ⋅erf⎝rc⋅╲╱ a₁ + a₂ ⎠ - 6⋅√π⋅a₁⋅rc ⋅╲╱
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#             2                                                  2
# ________  rc ⋅(a₁ + a₂)                       2   _________  rc ⋅(a₁ + a₂)
# a₁ + a₂ ⋅ℯ              + 2⋅a₁⋅rc + 6⋅√π⋅a₂⋅rc ⋅╲╱ a₁ + a₂ ⋅ℯ             ⋅erf
# ──────────────────────────────────────────────────────────────────────────────
#                                                                    ⎛  4
#                                                                 16⋅⎝a₁  + 4⋅a₁
#
#                                               2
# ⎛     _________⎞             2   _________  rc ⋅(a₁ + a₂)
# ⎝rc⋅╲╱ a₁ + a₂ ⎠ - 6⋅√π⋅a₂⋅rc ⋅╲╱ a₁ + a₂ ⋅ℯ              + 2⋅a₂⋅rc + 15⋅√π⋅╲╱
# ──────────────────────────────────────────────────────────────────────────────
# 3          2   2          3     4⎞
#  ⋅a₂ + 6⋅a₁ ⋅a₂  + 4⋅a₁⋅a₂  + a₂ ⎠
#
#              2                                                      2
# _________  rc ⋅(a₁ + a₂)    ⎛     _________⎞           _________  rc ⋅(a₁ + a₂
#  a₁ + a₂ ⋅ℯ             ⋅erf⎝rc⋅╲╱ a₁ + a₂ ⎠ - 15⋅√π⋅╲╱ a₁ + a₂ ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#  ⎞     2
# )⎟  -rc ⋅(a₁ + a₂)
#  ⎠⋅ℯ
# ───────────────────

# %%
Ws.factor()
# Out:
#  ⎛                              2       2
#  ⎜          2   _________  a₁⋅rc   a₂⋅rc     ⎛     _________⎞             2
# -⎝6⋅√π⋅a₁⋅rc ⋅╲╱ a₁ + a₂ ⋅ℯ      ⋅ℯ      ⋅erf⎝rc⋅╲╱ a₁ + a₂ ⎠ - 6⋅√π⋅a₁⋅rc ⋅╲╱
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                 2       2                                           2       2
# _________  a₁⋅rc   a₂⋅rc                        2   _________  a₁⋅rc   a₂⋅rc
#  a₁ + a₂ ⋅ℯ      ⋅ℯ       + 2⋅a₁⋅rc + 6⋅√π⋅a₂⋅rc ⋅╲╱ a₁ + a₂ ⋅ℯ      ⋅ℯ      ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                                     2       2
#    ⎛     _________⎞             2   _________  a₁⋅rc   a₂⋅rc
# erf⎝rc⋅╲╱ a₁ + a₂ ⎠ - 6⋅√π⋅a₂⋅rc ⋅╲╱ a₁ + a₂ ⋅ℯ      ⋅ℯ       + 2⋅a₂⋅rc + 15⋅√
# ──────────────────────────────────────────────────────────────────────────────
#                    4
#        16⋅(a₁ + a₂)
#
#                     2       2                                               2
#     _________  a₁⋅rc   a₂⋅rc     ⎛     _________⎞           _________  a₁⋅rc
# π⋅╲╱ a₁ + a₂ ⋅ℯ      ⋅ℯ      ⋅erf⎝rc⋅╲╱ a₁ + a₂ ⎠ - 15⋅√π⋅╲╱ a₁ + a₂ ⋅ℯ      ⋅
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#       2⎞        2        2
#  a₂⋅rc ⎟  -a₁⋅rc   -a₂⋅rc
# ℯ      ⎠⋅ℯ       ⋅ℯ
# ───────────────────────────

# %%
printing.sstrrepr(Ws)
# Out:
# '-(6*sqrt(pi)*a1*rc**2*sqrt(a1 + a2)*exp(rc**2*(a1 + a2))*erf(rc*sqrt(a1 + a2)) - 6*sqrt(pi)*a1*rc**2*sqrt(a1 + a2)*exp(rc**2*(a1 + a2)) + 2*a1*rc + 6*sqrt(pi)*a2*rc**2*sqrt(a1 + a2)*exp(rc**2*(a1 + a2))*erf(rc*sqrt(a1 + a2)) - 6*sqrt(pi)*a2*rc**2*sqrt(a1 + a2)*exp(rc**2*(a1 + a2)) + 2*a2*rc + 15*sqrt(pi)*sqrt(a1 + a2)*exp(rc**2*(a1 + a2))*erf(rc*sqrt(a1 + a2)) - 15*sqrt(pi)*sqrt(a1 + a2)*exp(rc**2*(a1 + a2)))*exp(-rc**2*(a1 + a2))/(16*(a1**4 + 4*a1**3*a2 + 6*a1**2*a2**2 + 4*a1*a2**3 + a2**4))'

# %%
W=integrate(gp*w, (x, rc, oo))
W
# Out:
#     ⎛⎛                            2⎞
#     ⎜⎜                       -a⋅rc ⎟ ⎛    2   4          2      ⎞      ⎛    3
#   7 ⎜⎝√π⋅√a⋅rc⋅erf(√a⋅rc) + ℯ      ⎠⋅⎝28⋅a ⋅rc  + 70⋅a⋅rc  + 105⎠   √π⋅⎝56⋅a ⋅
# rc ⋅⎜──────────────────────────────────────────────────────────── - ──────────
#     ⎜                             3   6
#     ⎝                         28⋅a ⋅rc
# ──────────────────────────────────────────────────────────────────────────────
#                                                                     2
#
#
#                                                            ⎞       ⎛
#   6        2   4           2      ⎞                        ⎟       ⎜  ⎛
# rc  + 140⋅a ⋅rc  + 210⋅a⋅rc  + 105⎠⋅erf(√a⋅rc)     15⋅√π   ⎟     7 ⎜  ⎝- 10⋅a⋅
# ────────────────────────────────────────────── + ──────────⎟   rc ⋅⎜- ────────
#                 7/2   7                             7/2   7⎟       ⎜
#             56⋅a   ⋅rc                           8⋅a   ⋅rc ⎠       ⎝
# ──────────────────────────────────────────────────────────── + ───────────────
#
#
#
#           ⎛                            2⎞
#   2     ⎞ ⎜                       -a⋅rc ⎟      ⎛      2   4          2     ⎞
# rc  - 15⎠⋅⎝√π⋅√a⋅rc⋅erf(√a⋅rc) + ℯ      ⎠   √π⋅⎝- 20⋅a ⋅rc  - 30⋅a⋅rc  - 15⎠⋅e
# ───────────────────────────────────────── + ──────────────────────────────────
#                 2   4                                           5/2   5
#             10⋅a ⋅rc                                        20⋅a   ⋅rc
# ──────────────────────────────────────────────────────────────────────────────
#                                           2
#
#
#                       ⎞
#                       ⎟
# rf(√a⋅rc)      3⋅√π   ⎟
# ───────── + ──────────⎟                                   2
#                5/2   5⎟      ⎛ 2   4         2    ⎞  -a⋅rc
#             4⋅a   ⋅rc ⎠   rc⋅⎝a ⋅rc  + 2⋅a⋅rc  + 2⎠⋅ℯ
# ─────────────────────── - ─────────────────────────────────
#                                            3
#                                           a

# %%
Wf=W.factor()
Wf
# Out:
#  ⎛                              2                               2
#  ⎜   13/2            7   2  a⋅rc                     7   2  a⋅rc           6
# -⎝2⋅a    ⋅rc + 6⋅√π⋅a ⋅rc ⋅ℯ     ⋅erf(√a⋅rc) - 6⋅√π⋅a ⋅rc ⋅ℯ      + 15⋅√π⋅a ⋅ℯ
# ──────────────────────────────────────────────────────────────────────────────
#                                                              19/2
#                                                          16⋅a
#
#     2                            2⎞       2
# a⋅rc                      6  a⋅rc ⎟  -a⋅rc
#      ⋅erf(√a⋅rc) - 15⋅√π⋅a ⋅ℯ     ⎠⋅ℯ
# ────────────────────────────────────────────

# %%
Wf.simplify()
# Out:
#            2
#       -a⋅rc           2                     2
#   rc⋅ℯ         3⋅√π⋅rc ⋅erf(√a⋅rc)   3⋅√π⋅rc    15⋅√π⋅erf(√a⋅rc)    15⋅√π
# - ────────── - ─────────────────── + ──────── - ──────────────── + ───────
#         3                5/2             5/2            7/2            7/2
#      8⋅a              8⋅a             8⋅a           16⋅a           16⋅a

# %%
printing.sstrrepr(Wf.simplify())
# Out:
# '-rc*exp(-a*rc**2)/(8*a**3) - 3*sqrt(pi)*rc**2*erf(sqrt(a)*rc)/(8*a**(5/2)) + 3*sqrt(pi)*rc**2/(8*a**(5/2)) - 15*sqrt(pi)*erf(sqrt(a)*rc)/(16*a**(7/2)) + 15*sqrt(pi)/(16*a**(7/2))'
